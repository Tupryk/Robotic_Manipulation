# %% [markdown]
# # Manipulation.py: Bridge

# %%
import numpy as np
import robotic as ry
import manipulation as manip

# %%
C = ry.Config()
C.addFile(ry.raiPath('../rai-robotModels/scenarios/pandaSingle.g'))

for i in range(3):
	# Frame name
	box_name = f"box{i+1}"

	# Box color
	color = [0, 0, 0]
	color[i] = 1

	# Position
	position_val1 = 0.2 * i + .3

	C.addFrame(box_name) \
		.setPosition([position_val1, 0.05, 0.72]) \
		.setShape(ry.ST.ssBox, size=[0.04, 0.04, 0.12, 0.001]) \
		.setColor(color) \
		.setContact(1) \
		.setMass(.1)

C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
gripper = "l_gripper"
palm = "l_palm"
boxes = [f"box{i}" for i in range(1, 4)]
table = "table"

C.view()
# Out:
# 0

# %%
from time import sleep

def build_bridge(target_position: list[float], vis: bool=False) -> bool:
	boxes = ["box1", "box2", "box3"]
	
	# Pick place waypoints
	M = manip.ManipulationModelling(C, helpers=[gripper])
	M.setup_pick_and_place_sequence(gripper, table, boxes)

	# Box 1
	grasp_direction = np.random.choice(["x", "y"])
	M.grasp_box(1., gripper, "box1", palm, grasp_direction)
	M.place_box(2., "box1", table, palm, "z")
	M.target_relative_xy_position(2., "box1", table, target_position)

	# Box 2
	grasp_direction = np.random.choice(["x", "y"])
	M.grasp_box(3., gripper, "box2", palm, grasp_direction)
	M.place_box(4., "box2", table, palm, "z")
	M.set_relative_distance(4., "box1", "box2", .05)

	# Box 3
	grasp_direction = np.random.choice(["x", "y"])
	M.grasp_box(5., gripper, "box3", palm, grasp_direction)
	place_direction = ry.FS.vectorX if grasp_direction == "y" else ry.FS.vectorY
	# M.komo.addObjective([6.], ry.FS.vectorZ, ["box3"], ry.OT.eq, [1e1], box3_dir)
	M.komo.addObjective([6.], place_direction, ["box3"], ry.OT.eq, [1e1], [0, 0, -1])
	M.komo.addObjective([6.], ry.FS.positionRel, ["box3", "box1"], ry.OT.sos, 1e1*np.array([[1, 0, 0],[0, 1, 0]]), 0)
	M.komo.addObjective([6.], ry.FS.positionRel, ["box3", "box2"], ry.OT.sos, 1e1*np.array([[1, 0, 0],[0, 1, 0]]), 0)
	M.set_relative_distance(6., "box3", "box1", .0)

	
	M.solve()

	keypoints = M.solve()
	if not M.feasible:
		# M.komo.report(plotOverTime=True)
		# C.view(True, f"{M.feasible}")
		return False, []
	
	# for i, k in enumerate(keypoints):
	# 	C.setJointState(k)
	# 	if i%2:
	# 		C.attach(table, boxes[i//2])
	# 	else:
	# 		C.attach(gripper, boxes[i//2])
	# 	C.view(False, f'step {i}')
	# 	sleep(1.)

	# return True, keypoints
	
	paths = []
	manip_models = []
	
	# Sub motions
	for i, box in enumerate(boxes):
		idx = i*2
		M1 = M.sub_motion(idx, accumulated_collisions=True)
		M1.retract([.0, .2], gripper)
		M1.approach([.8, 1.], gripper)
		path = M1.solve()
		if not M1.feasible:
			return False, []
		paths.append(path)
		manip_models.append(M1)

		M2 = M.sub_motion(idx+1, accumulated_collisions=True)
		path = M2.solve()
		if not M2.feasible:
			return False, []
		paths.append(path)
		manip_models.append(M2)

	# Visualization
	if vis:
		for i, m in enumerate(manip_models):
			m.play(C, 1.)
			if i%2:
				C.attach(table, boxes[i//2])
			else:
				C.attach(gripper, boxes[i//2])

	return True, paths

# %%
attempt_count = 30
success_count = 0
midpoint = [-0.105, 0.4, 0.745]

for l in range(attempt_count):
	housePosition = [midpoint[0] + np.random.random()*.2 -.1, midpoint[1] + np.random.random()*.2]
	success, _ = build_bridge(housePosition, vis=True)
	success_count += 1 if success else 0
	
print(f"Successful motions: {success_count}/{attempt_count}")
# Out:
#   -- infeasible:
#      { time: 0.878523, evals: 186, done: 1, feasible: 0, sos: 0.301441, f: 0, ineq: 0.0667105, eq: 2.52535 }
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
#   -- infeasible:
#      { time: 0.508312, evals: 163, done: 1, feasible: 0, sos: 0.292886, f: 0, ineq: 0.0983977, eq: 3.0065 }
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting me  -- infeasible:
#      { time: 0.186705, evals: 70, done: 1, feasible: 0, sos: 0.632533, f: 0, ineq: 4.82, eq: 23.6249 }
#   -- infeasible:
#      { time: 0.162073, evals: 63, done: 1, feasible: 0, sos: 0.437325, f: 0, ineq: 4.13415, eq: 19.8072 }
# shes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non interse  -- infeasible:
#      { time: 0.510741, evals: 177, done: 1, feasible: 0, sos: 0.506881, f: 0, ineq: 0.19053, eq: 2.35664 }
#   -- infeasible:
#      { time: 0.601083, evals: 201, done: 1, feasible: 0, sos: 0.501748, f: 0, ineq: 0.132489, eq: 2.18662 }
#   -- feasible:
#      { time: 0.648736, evals: 200, done: 1, feasible: 1, sos: 0.769293, f: 0, ineq: 0.00953387, eq: 0.128077 }
#   -- infeasible:
#      { time: 0.622564, evals: 201, done: 1, feasible: 0, sos: 0.427019, f: 0, ineq: 0.276246, eq: 2.05729 }
#   -- infeasible:
#      { time: 0.613894, evals: 201, done: 1, feasible: 0, sos: 0.303829, f: 0, ineq: 0.0932244, eq: 1.64368 }
# cting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration  -- feasible:
#      { time: 0.427413, evals: 145, done: 1, feasible: 1, sos: 0.681081, f: 0, ineq: 0.000372568, eq: 0.00475703 }
#  for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR pen  -- feasible:sub_motion_0--
#      { time: 0.091044, evals: 26, done: 1, feasible: 1, sos: 2.28188, f: 0, ineq: 5.95406e-06, eq: 0.0020182 }
# etration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
#   -- feasible:sub_motion_1--
#      { time: 0.015171, evals: 7, done: 1, feasible: 1, sos: 0.315791, f: 0, ineq: 0, eq: 0.00012323 }
#   -- feasible:sub_motion_2--
#      { time: 0.052565, evals: 22, done: 1, feasible: 1, sos: 3.04211, f: 0, ineq: 6.62594e-07, eq: 0.000318451 }
#   -- feasible:sub_motion_3--
#      { time: 0.036611, evals: 11, done: 1, feasible: 1, sos: 0.326575, f: 0, ineq: 0, eq: 0.000231937 }
#   -- feasible:sub_motion_4--
#      { time: 0.118897, evals: 35, done: 1, feasible: 1, sos: 0.901354, f: 0, ineq: 1.70782e-06, eq: 0.000349298 }
#   -- feasible:sub_motion_5--
#      { time: 0.131482, evals: 40, done: 1, feasible: 1, sos: 0.297185, f: 0, ineq: 0, eq: 0.000502186 }
# len 6
#   -- infeasible:
#      { time: 0.770086, evals: 200, done: 1, feasible: 0, sos: 0.414237, f: 0, ineq: 0.254555, eq: 4.14424 }
#   -- infeasible:
#      { time: 0.167659, evals: 50, done: 1, feasible: 0, sos: 0.283257, f: 0, ineq: 0.438744, eq: 11.031 }
#   -- infeasible:
#      { time: 0.724208, evals: 200, done: 1, feasible: 0, sos: 0.501775, f: 0, ineq: 0.198172, eq: 1.45678 }
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
#   -- infeasible:
#      { time: 0.739814, evals: 200, done: 1, feasible: 0, sos: 0.26624, f: 0, ineq: 0.252435, eq: 2.20545 }
#   -- infeasible:
#      { time: 0.778599, evals: 201, done: 1, feasible: 0, sos: 0.545382, f: 0, ineq: 0.174676, eq: 1.57917 }
#   -- infeasible:
#      { time: 0.712273, evals: 201, done: 1, feasible: 0, sos: 0.606262, f: 0, ineq: 0.179965, eq: 1.21448 }
#   -- feasible:
#      { time: 0.661192, evals: 201, done: 1, feasible: 1, sos: 0.638108, f: 0, ineq: 0.13357, eq: 0.400095 }
#   -- feasible:
#      { time: 0.962872, evals: 201, done: 1, feasible: 1, sos: 0.613695, f: 0, ineq: 0.144479, eq: 0.295096 }
#   -- feasible:sub_motion_0--
#      { time: 0.507937, evals: 82, done: 1, feasible: 1, sos: 1.3552, f: 0, ineq: 7.58456e-07, eq: 0.0378415 }
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
#   -- feasible:sub_motion_1--
#      { time: 0.71486, evals: 184, done: 1, feasible: 1, sos: 0.0948413, f: 0, ineq: 0, eq: 0.0426032 }
#   -- feasible:sub_motion_2--
#      { time: 0.501841, evals: 93, done: 1, feasible: 1, sos: 3.54903, f: 0, ineq: 1.91591e-07, eq: 0.00356041 }
#   -- feasible:sub_motion_3--
#      { time: 0.098247, evals: 16, done: 1, feasible: 1, sos: 0.0503847, f: 0, ineq: 0, eq: 0.0119317 }
#   -- feasible:sub_motion_4--
#      { time: 0.471136, evals: 79, done: 1, feasible: 1, sos: 1.22763, f: 0, ineq: 3.11638e-05, eq: 0.00814113 }
#   -- feasible:sub_motion_5--
#      { time: 1.16085, evals: 197, done: 1, feasible: 1, sos: 0.322963, f: 0, ineq: 0, eq: 0.00559122 }
# len 6
#   -- infeasible:
#      { time: 0.585291, evals: 200, done: 1, feasible: 0, sos: 0.236996, f: 0, ineq: 0.238219, eq: 2.2684 }
#   -- infeasible:
#      { time: 0.670939, evals: 200, done: 1, feasible: 0, sos: 0.276802, f: 0, ineq: 0.184035, eq: 1.70277 }
#   -- infeasible:
#      { time: 0.636174, evals: 201, done: 1, feasible: 0, sos: 0.538122, f: 0, ineq: 0.276779, eq: 1.68082 }
#   -- infeasible:
#      { time: 0.69739, evals: 201, done: 1, feasible: 0, sos: 0.492914, f: 0, ineq: 0.271979, eq: 1.72314 }
#   -- infeasible:
#      { time: 0.262642, evals: 77, done: 1, feasible: 0, sos: 0.327574, f: 0, ineq: 0.545185, eq: 3.97657 }
#   -- infeasible:
#      { time: 0.646272, evals: 200, done: 1, feasible: 0, sos: 0.319731, f: 0, ineq: 0.467917, eq: 3.0649 }
#   -- infeasible:
#      { time: 0.251848, evals: 68, done: 1, feasible: 0, sos: 0.305093, f: 0, ineq: 0.511349, eq: 4.70201 }
#   -- infeasible:
#      { time: 0.166152, evals: 51, done: 1, feasible: 0, sos: 0.479648, f: 0, ineq: 0.763178, eq: 11.9181 }
#   -- infeasible:
#      { time: 0.341627, evals: 95, done: 1, feasible: 0, sos: 0.249334, f: 0, ineq: 0.195237, eq: 2.62131 }
#   -- infeasible:
#      { time: 0.829199, evals: 200, done: 1, feasible: 0, sos: 0.263269, f: 0, ineq: 0.205078, eq: 3.55502 }
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
# -- pairCollision.cpp:libccd:354(0) WARNING: called MPR penetration for non intersecting meshes...
# -- pairCollision.cpp:libccd:359(0) WARNING: but GJK says intersection
#   -- infeasible:
#      { time: 0.84047, evals: 200, done: 1, feasible: 0, sos: 0.215199, f: 0, ineq: 0.336919, eq: 2.01007 }
#   -- infeasible:
#      { time: 0.784953, evals: 201, done: 1, feasible: 0, sos: 0.214738, f: 0, ineq: 0.296824, eq: 1.90075 }
#   -- infeasible:
#      { time: 0.456915, evals: 96, done: 1, feasible: 0, sos: 0.306175, f: 0, ineq: 0.343618, eq: 6.42789 }
#   -- infeasible:
#      { time: 0.214309, evals: 62, done: 1, feasible: 0, sos: 0.357534, f: 0, ineq: 0.274212, eq: 7.40155 }
#   -- infeasible:
#      { time: 0.25501, evals: 81, done: 1, feasible: 0, sos: 0.247488, f: 0, ineq: 0.54567, eq: 4.97956 }
